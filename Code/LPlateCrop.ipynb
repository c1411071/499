# %%
#201411064 R.Kaan Varlı
#201411071 Mert Yumuşak

import urllib.request
url = "https://github.com/c1411071/499/tree/master/License%20Plate%20Dataset" 
print ("download start!")
filename, headers = urllib.request.urlretrieve(url, filename="C:\Masaüstü\imagedata") # We are importing our data here.
print ("download complete!")
print ("download file location: ", filename)
print ("download headers: ", headers)

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/1.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((80,100,195,145))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/2.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((79,134,151,160))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/3.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((75,112,130,130))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/4.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((133,72,206,99))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/5.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((85,124,137,147))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/6.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((100,162,171,182))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/7.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((66,124,123,142))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/8.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((61,139,169,166))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/9.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((70,157,153,185))

 

# Display the cropped portion

cropped.show()

# %%
# import the Python Image processing Library

from PIL import Image

 

# Create an Image object from an Image

imageObject  = Image.open("/10.jpg")

 

# Crop the plate portion

cropped     = imageObject.crop((73,122,162,148))

 

# Display the cropped portion

cropped.show()
